# %% [markdown]
# # Convolutional Autoeconder with two decoders
# This code trains a simple autoencoder neural network using convolutional
# layers. However, an additional decoder is compled to the bottleneck where
# the decoder output is trained with next time step.The contraction and
# expansion of the implemented neural network used only convolutional layers.
# Therefore, it does not rely on maxpooling or upsampling layers. Instead,
# it was used strides to control the contraction and expansion of the neural
# network. Also, in the decoder part it was used a decovolutional process.
#
# For the latent space it was used a fully connected layer with an additional
# fully connected layer in sequence, to connect the latent space with the
# decoder convolutional layer.
#
# The neural network architecture with the activation function is stated below.

# %% [markdown]
# ## Prelimiary steps

# %%
# Optional cell if the current path already has the data and the file utils.py
# %cd .. 
# %cd ..

# %%
# Import modules
import h5py
import keras.layers as layers
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.models import Model

from utils import plot_red_comp, slicer, split, format_data


# Path to store training data
save_path = "./tests/jupyter-notebooks/models/train_dual_model_{}"
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ###  Data manipulation

# %%
# Selecting data
dt_fl = "nn_data.h5"
dt_dst = "scaled_data"

# The percentage for the test is implicit
n_train = 0.8
n_valid = 0.1

# Select the variable to train
# 0: Temperature - 1: Pressure - 2: Velocity - None: all
var = 2

# %% [markdown]
# Load the selected data and then split it.

# %%
# Open data file
f = h5py.File(dt_fl, "r")
dt = f[dt_dst]

x_data, y_data = format_data(dt, wd=2, var=2, get_y=True, cont=True)
x_data = x_data[:,0]

# Split data file
idxs = split(x_data.shape[0], n_train, n_valid)
slc_trn, slc_vld, slc_tst = slicer(x_data.shape, idxs)
# Slice data
x_train = x_data[slc_trn]
y_train = y_data[slc_trn]
x_val = x_data[slc_vld]
y_val = y_data[slc_vld]

# %% [markdown]
# ### Autoencoder settings

# %%
# Activation function
act = "tanh"  # Convolutional layers activation function
act_lt = "tanh"  # Latent space layers activation function
# Number of filters of each layer
flt = [3, 9, 27]
# Filter size
flt_size = 5
# Strides of each layer
strd = [2, 2, 5]
# Latent space size
lt_sz = 50

# Training settings
opt = "adam"  # Optimizer
loss = "mse"
epochs = 60
batch_size = 64

# %% [markdown]
# ### Build autoencoder

# %%
# Build the autoencoder neural network
tf.keras.backend.clear_session()
flt_tp = (flt_size, flt_size)
conv_kwargs = dict(activation=act, padding="same")
# Encoder
inputs = layers.Input(shape=x_train.shape[1:])
e = layers.Conv2D(flt[0], flt_tp, strides=strd[0], **conv_kwargs)(inputs)
e = layers.Conv2D(flt[1], flt_tp, strides=strd[1], **conv_kwargs)(e)
e = layers.Conv2D(flt[2], flt_tp, strides=strd[2], **conv_kwargs)(e)

# Latent space
l = layers.Flatten()(e)
l = layers.Dense(lt_sz, activation=act_lt)(l)

# Latent to decoder same
dn_flt = flt[-1]
d_shp = (x_train.shape[1:-1] / np.prod(strd)).astype(int)
d_sz = np.prod(d_shp) * dn_flt
d = layers.Dense(d_sz, activation=act_lt)(l)
d = layers.Reshape(np.hstack((d_shp, dn_flt)))(d)
# Decoder same
d = layers.Conv2DTranspose(flt[-1], flt_tp, strides=strd[-1], **conv_kwargs)(d)
d = layers.Conv2DTranspose(flt[-2], flt_tp, strides=strd[-2], **conv_kwargs)(d)
d = layers.Conv2DTranspose(flt[-3], flt_tp, strides=strd[-3], **conv_kwargs)(d)
decoded = layers.Conv2DTranspose(
    x_train.shape[-1], flt_tp, activation="linear", padding="same", name="dec_same"
)(d)
# Decoder next step
dp = layers.Dense(d_sz, activation=act_lt)(l)
dp = layers.Reshape(np.hstack((d_shp, dn_flt)))(dp)
# Decoder same
dp = layers.Conv2DTranspose(flt[-1], flt_tp, strides=strd[-1], **conv_kwargs)(dp)
dp = layers.Conv2DTranspose(flt[-2], flt_tp, strides=strd[-2], **conv_kwargs)(dp)
dp = layers.Conv2DTranspose(flt[-3], flt_tp, strides=strd[-3], **conv_kwargs)(dp)
decoded_pred = layers.Conv2DTranspose(
    x_train.shape[-1], flt_tp, activation="linear", padding="same", name="dec_pred"
)(dp)

# Mount the autoencoder
ae = Model(inputs, [decoded, decoded_pred], name="Dual Convolutional Autoencoder")

# %%
# Show the architecture
ae.summary()
# Out:
# Model: "Dual Convolutional Autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 100, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 50, 3)   78          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 25, 9)    684         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 5, 27)    6102        conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1350)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           67550       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1350)         68850       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1350)         68850       dense_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 10, 5, 27)    0           dense_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 10, 5, 27)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 50, 25, 27)   18252       reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 50, 25, 27)   18252       reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 100, 50, 9)   6084        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 100, 50, 9)   6084        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 200, 100, 3)  678         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 200, 100, 3)  678         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# dec_same (Conv2DTranspose)      (None, 200, 100, 1)  76          conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# dec_pred (Conv2DTranspose)      (None, 200, 100, 1)  76          conv2d_transpose_6[0][0]
# ==================================================================================================
# Total params: 262,294
# Trainable params: 262,294
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Callbacks
# Early stopping to stop training when the validation loss start to increase
# The patience term is a number of epochs to wait before stop. Also, the
# 'restore_best_weights' is used to restore the best model against the
# validation dataset. It is necessary as not always the best model against
# the validation dataset is the last neural network weights.

# %%
# Callbacks
monitor = "val_dec_pred_loss"
patience = int(epochs * 0.3)
es = EarlyStopping(
    monitor=monitor, mode="min", patience=patience, restore_best_weights=True
)

# %% [markdown]
# ### Training

# %%
# Compile and train
ae.compile(optimizer=opt, loss=loss)
hist = ae.fit(
    x_train,
    [x_train, y_train],
    epochs=epochs,
    batch_size=batch_size,
    shuffle=True,
    validation_data=(x_val, [x_val, y_val]),
    callbacks=[es],
)
# Out:
# Train on 1121 samples, validate on 140 samples
# Epoch 1/60
# 1121/1121 [==============================] - 4s 4ms/step - loss: 1.7597 - dec_same_loss: 0.8518 - dec_pred_loss: 0.9030 - val_loss: 1.4323 - val_dec_same_loss: 0.5540 - val_dec_pred_loss: 0.5478
# Epoch 2/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 1.2283 - dec_same_loss: 0.6011 - dec_pred_loss: 0.6240 - val_loss: 1.0489 - val_dec_same_loss: 0.3710 - val_dec_pred_loss: 0.4033
# Epoch 3/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.8893 - dec_same_loss: 0.4280 - dec_pred_loss: 0.4547 - val_loss: 0.7857 - val_dec_same_loss: 0.2768 - val_dec_pred_loss: 0.3037
# Epoch 4/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.7126 - dec_same_loss: 0.3393 - dec_pred_loss: 0.3720 - val_loss: 0.6805 - val_dec_same_loss: 0.2347 - val_dec_pred_loss: 0.2667
# Epoch 5/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.6111 - dec_same_loss: 0.2877 - dec_pred_loss: 0.3258 - val_loss: 0.5987 - val_dec_same_loss: 0.2031 - val_dec_pred_loss: 0.2376
# Epoch 6/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.5365 - dec_same_loss: 0.2467 - dec_pred_loss: 0.2897 - val_loss: 0.5427 - val_dec_same_loss: 0.1792 - val_dec_pred_loss: 0.2209
# Epoch 7/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.4779 - dec_same_loss: 0.2158 - dec_pred_loss: 0.2616 - val_loss: 0.5126 - val_dec_same_loss: 0.1646 - val_dec_pred_loss: 0.2126
# Epoch 8/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.4405 - dec_same_loss: 0.1965 - dec_pred_loss: 0.2442 - val_loss: 0.4811 - val_dec_same_loss: 0.1509 - val_dec_pred_loss: 0.2026
# Epoch 9/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.4151 - dec_same_loss: 0.1799 - dec_pred_loss: 0.2294 - val_loss: 0.4675 - val_dec_same_loss: 0.1438 - val_dec_pred_loss: 0.1999
# Epoch 10/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3960 - dec_same_loss: 0.1727 - dec_pred_loss: 0.2232 - val_loss: 0.4595 - val_dec_same_loss: 0.1409 - val_dec_pred_loss: 0.1994
# Epoch 11/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3791 - dec_same_loss: 0.1643 - dec_pred_loss: 0.2153 - val_loss: 0.4476 - val_dec_same_loss: 0.1345 - val_dec_pred_loss: 0.1962
# Epoch 12/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3666 - dec_same_loss: 0.1587 - dec_pred_loss: 0.2098 - val_loss: 0.4276 - val_dec_same_loss: 0.1260 - val_dec_pred_loss: 0.1885
# Epoch 13/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3499 - dec_same_loss: 0.1509 - dec_pred_loss: 0.2014 - val_loss: 0.4169 - val_dec_same_loss: 0.1215 - val_dec_pred_loss: 0.1846
# Epoch 14/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3362 - dec_same_loss: 0.1429 - dec_pred_loss: 0.1927 - val_loss: 0.4111 - val_dec_same_loss: 0.1172 - val_dec_pred_loss: 0.1844
# Epoch 15/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3247 - dec_same_loss: 0.1378 - dec_pred_loss: 0.1877 - val_loss: 0.4030 - val_dec_same_loss: 0.1151 - val_dec_pred_loss: 0.1806
# Epoch 16/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3152 - dec_same_loss: 0.1325 - dec_pred_loss: 0.1812 - val_loss: 0.4006 - val_dec_same_loss: 0.1130 - val_dec_pred_loss: 0.1809
# Epoch 17/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3091 - dec_same_loss: 0.1316 - dec_pred_loss: 0.1781 - val_loss: 0.3942 - val_dec_same_loss: 0.1114 - val_dec_pred_loss: 0.1788
# Epoch 18/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.3015 - dec_same_loss: 0.1281 - dec_pred_loss: 0.1747 - val_loss: 0.3895 - val_dec_same_loss: 0.1090 - val_dec_pred_loss: 0.1767
# Epoch 19/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2943 - dec_same_loss: 0.1247 - dec_pred_loss: 0.1706 - val_loss: 0.3867 - val_dec_same_loss: 0.1073 - val_dec_pred_loss: 0.1763
# Epoch 20/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2870 - dec_same_loss: 0.1228 - dec_pred_loss: 0.1663 - val_loss: 0.3818 - val_dec_same_loss: 0.1040 - val_dec_pred_loss: 0.1759
# Epoch 21/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2819 - dec_same_loss: 0.1189 - dec_pred_loss: 0.1627 - val_loss: 0.3785 - val_dec_same_loss: 0.1029 - val_dec_pred_loss: 0.1744
# Epoch 22/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2761 - dec_same_loss: 0.1167 - dec_pred_loss: 0.1592 - val_loss: 0.3756 - val_dec_same_loss: 0.1020 - val_dec_pred_loss: 0.1732
# Epoch 23/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2720 - dec_same_loss: 0.1160 - dec_pred_loss: 0.1578 - val_loss: 0.3749 - val_dec_same_loss: 0.1006 - val_dec_pred_loss: 0.1740
# Epoch 24/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2675 - dec_same_loss: 0.1122 - dec_pred_loss: 0.1527 - val_loss: 0.3707 - val_dec_same_loss: 0.0995 - val_dec_pred_loss: 0.1719
# Epoch 25/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2630 - dec_same_loss: 0.1123 - dec_pred_loss: 0.1525 - val_loss: 0.3710 - val_dec_same_loss: 0.0996 - val_dec_pred_loss: 0.1722
# Epoch 26/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2595 - dec_same_loss: 0.1108 - dec_pred_loss: 0.1499 - val_loss: 0.3682 - val_dec_same_loss: 0.0983 - val_dec_pred_loss: 0.1715
# Epoch 27/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2564 - dec_same_loss: 0.1095 - dec_pred_loss: 0.1470 - val_loss: 0.3653 - val_dec_same_loss: 0.0969 - val_dec_pred_loss: 0.1706
# Epoch 28/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2544 - dec_same_loss: 0.1089 - dec_pred_loss: 0.1457 - val_loss: 0.3698 - val_dec_same_loss: 0.0963 - val_dec_pred_loss: 0.1746
# Epoch 29/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2531 - dec_same_loss: 0.1087 - dec_pred_loss: 0.1448 - val_loss: 0.3623 - val_dec_same_loss: 0.0960 - val_dec_pred_loss: 0.1693
# Epoch 30/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2489 - dec_same_loss: 0.1066 - dec_pred_loss: 0.1420 - val_loss: 0.3624 - val_dec_same_loss: 0.0957 - val_dec_pred_loss: 0.1699
# Epoch 31/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2459 - dec_same_loss: 0.1059 - dec_pred_loss: 0.1404 - val_loss: 0.3608 - val_dec_same_loss: 0.0947 - val_dec_pred_loss: 0.1694
# Epoch 32/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2429 - dec_same_loss: 0.1049 - dec_pred_loss: 0.1380 - val_loss: 0.3599 - val_dec_same_loss: 0.0942 - val_dec_pred_loss: 0.1692
# Epoch 33/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2408 - dec_same_loss: 0.1043 - dec_pred_loss: 0.1366 - val_loss: 0.3592 - val_dec_same_loss: 0.0938 - val_dec_pred_loss: 0.1692
# Epoch 34/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2386 - dec_same_loss: 0.1039 - dec_pred_loss: 0.1355 - val_loss: 0.3590 - val_dec_same_loss: 0.0937 - val_dec_pred_loss: 0.1691
# Epoch 35/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2367 - dec_same_loss: 0.1041 - dec_pred_loss: 0.1355 - val_loss: 0.3579 - val_dec_same_loss: 0.0931 - val_dec_pred_loss: 0.1688
# Epoch 36/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2347 - dec_same_loss: 0.1029 - dec_pred_loss: 0.1333 - val_loss: 0.3567 - val_dec_same_loss: 0.0928 - val_dec_pred_loss: 0.1683
# Epoch 37/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2333 - dec_same_loss: 0.1018 - dec_pred_loss: 0.1316 - val_loss: 0.3577 - val_dec_same_loss: 0.0931 - val_dec_pred_loss: 0.1685
# Epoch 38/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2321 - dec_same_loss: 0.1014 - dec_pred_loss: 0.1302 - val_loss: 0.3575 - val_dec_same_loss: 0.0928 - val_dec_pred_loss: 0.1687
# Epoch 39/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2314 - dec_same_loss: 0.1008 - dec_pred_loss: 0.1285 - val_loss: 0.3575 - val_dec_same_loss: 0.0929 - val_dec_pred_loss: 0.1687
# Epoch 40/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2306 - dec_same_loss: 0.1017 - dec_pred_loss: 0.1304 - val_loss: 0.3580 - val_dec_same_loss: 0.0926 - val_dec_pred_loss: 0.1695
# Epoch 41/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2297 - dec_same_loss: 0.1009 - dec_pred_loss: 0.1281 - val_loss: 0.3560 - val_dec_same_loss: 0.0926 - val_dec_pred_loss: 0.1679
# Epoch 42/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2282 - dec_same_loss: 0.0999 - dec_pred_loss: 0.1267 - val_loss: 0.3548 - val_dec_same_loss: 0.0920 - val_dec_pred_loss: 0.1676
# Epoch 43/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2268 - dec_same_loss: 0.1011 - dec_pred_loss: 0.1268 - val_loss: 0.3553 - val_dec_same_loss: 0.0924 - val_dec_pred_loss: 0.1676
# Epoch 44/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2249 - dec_same_loss: 0.1002 - dec_pred_loss: 0.1260 - val_loss: 0.3562 - val_dec_same_loss: 0.0918 - val_dec_pred_loss: 0.1687
# Epoch 45/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2248 - dec_same_loss: 0.1010 - dec_pred_loss: 0.1268 - val_loss: 0.3595 - val_dec_same_loss: 0.0945 - val_dec_pred_loss: 0.1695
# Epoch 46/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2246 - dec_same_loss: 0.1001 - dec_pred_loss: 0.1252 - val_loss: 0.3546 - val_dec_same_loss: 0.0926 - val_dec_pred_loss: 0.1670
# Epoch 47/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2234 - dec_same_loss: 0.0990 - dec_pred_loss: 0.1231 - val_loss: 0.3582 - val_dec_same_loss: 0.0927 - val_dec_pred_loss: 0.1695
# Epoch 48/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2221 - dec_same_loss: 0.0991 - dec_pred_loss: 0.1228 - val_loss: 0.3571 - val_dec_same_loss: 0.0929 - val_dec_pred_loss: 0.1683
# Epoch 49/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2211 - dec_same_loss: 0.0989 - dec_pred_loss: 0.1217 - val_loss: 0.3559 - val_dec_same_loss: 0.0916 - val_dec_pred_loss: 0.1689
# Epoch 50/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2200 - dec_same_loss: 0.0998 - dec_pred_loss: 0.1223 - val_loss: 0.3541 - val_dec_same_loss: 0.0918 - val_dec_pred_loss: 0.1674
# Epoch 51/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2200 - dec_same_loss: 0.0988 - dec_pred_loss: 0.1213 - val_loss: 0.3564 - val_dec_same_loss: 0.0932 - val_dec_pred_loss: 0.1683
# Epoch 52/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2218 - dec_same_loss: 0.0995 - dec_pred_loss: 0.1221 - val_loss: 0.3555 - val_dec_same_loss: 0.0929 - val_dec_pred_loss: 0.1674
# Epoch 53/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2211 - dec_same_loss: 0.0993 - dec_pred_loss: 0.1213 - val_loss: 0.3577 - val_dec_same_loss: 0.0925 - val_dec_pred_loss: 0.1693
# Epoch 54/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2194 - dec_same_loss: 0.0987 - dec_pred_loss: 0.1204 - val_loss: 0.3586 - val_dec_same_loss: 0.0930 - val_dec_pred_loss: 0.1700
# Epoch 55/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2180 - dec_same_loss: 0.0983 - dec_pred_loss: 0.1198 - val_loss: 0.3551 - val_dec_same_loss: 0.0915 - val_dec_pred_loss: 0.1686
# Epoch 56/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2171 - dec_same_loss: 0.0976 - dec_pred_loss: 0.1193 - val_loss: 0.3570 - val_dec_same_loss: 0.0921 - val_dec_pred_loss: 0.1692
# Epoch 57/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2155 - dec_same_loss: 0.0984 - dec_pred_loss: 0.1193 - val_loss: 0.3530 - val_dec_same_loss: 0.0916 - val_dec_pred_loss: 0.1666
# Epoch 58/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2147 - dec_same_loss: 0.0961 - dec_pred_loss: 0.1163 - val_loss: 0.3564 - val_dec_same_loss: 0.0918 - val_dec_pred_loss: 0.1688
# Epoch 59/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2132 - dec_same_loss: 0.0964 - dec_pred_loss: 0.1160 - val_loss: 0.3552 - val_dec_same_loss: 0.0918 - val_dec_pred_loss: 0.1679
# Epoch 60/60
# 1121/1121 [==============================] - 2s 2ms/step - loss: 0.2130 - dec_same_loss: 0.0964 - dec_pred_loss: 0.1159 - val_loss: 0.3554 - val_dec_same_loss: 0.0915 - val_dec_pred_loss: 0.1684

# %% [markdown]
# ### Save trained model

# %%
# Save the model
ae.save(save_path.format("model.h5"))

# Store the test dataset
x_tst = dt[slc_tst][:, :, :, np.newaxis]
np.save(save_path.format("test.npy"), x_tst)

# %% [markdown]
# ### Training process

# %%
# Convert the history to a Pandas dataframe
hist_df = pd.DataFrame(hist.history)
hist_df.index.name = "Epochs"
# Save the training history
hist_df.to_hdf(save_path.format("hist.h5"), 'his')

# Plot training evolution
tit = "Validation loss: {:.3f} - Training loss: {:.3f}".format(*hist_df.min())
hist_df.plot(grid=True, title=tit)

# %% [markdown]
# ### Evaluate the trained model

# %%
# Test the trained neural network against the test dataset
x_test = x_data[slc_tst]
y_test = y_data[slc_tst]
loss = ae.evaluate(x_test, [x_test, y_test])
print("Test dataset loss - Same: {:.3f} - Next: {:.3f}".format(*loss[1:]))

global_loss = ae.evaluate(x_data, [x_data, y_data])
print("Entire dataset loss - Same: {:.3f} - Next: {:.3f}".format(*global_loss[1:]))
# Out:
# 140/140 [==============================] - 0s 2ms/step
# Test dataset loss - Same: 0.131 - Next: 0.223
# 1401/1401 [==============================] - 1s 1ms/step
# Entire dataset loss - Same: 0.103 - Next: 0.139

# %%
# Comparing the input and output of the autoencoder neural network
data_index = 634

# Slice the data
dt_in = x_data[data_index]
# Get the neural network output
dt_out, dt_out_nxt = ae.predict(dt_in[np.newaxis])
# Plot
alg = "Dual Convolutional Autoencoder"

# %% [markdown]
# Current time reconstruction

# %%
plot_red_comp(dt_in, dt_out[0], 0, lt_sz, global_loss[1], alg)

# %% [markdown]
# Next time step prediction

# %%
plot_red_comp(y_data[data_index], dt_out_nxt[0], 0, lt_sz, global_loss[2], alg)
