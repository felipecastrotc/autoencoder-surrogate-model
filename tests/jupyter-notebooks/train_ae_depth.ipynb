# %% [markdown]
# # Depthwise Convolutional Autoeconder
#
# This code trains a simple autoencoder neural network using convolutional
# layers. However, differently from the default convolutional layers, the
# depthwise convolutional layer acts on each input channel separately. The
# contraction and expansion of the implemented neural network used only
# convolutional layers. Therefore, it does not rely on maxpooling or upsampling
# layers. Instead, it was used strides to control the contraction and expansion
# of the neural network. Also, in the decoder part it was used a decovolutional
# process.
#
# For the latent space it was used a fully connected layer with an additional
# fully connected layer in sequence, to connect the latent space with the
# decoder convolutional layer.
#
# The neural network architecture with the activation function is stated below.

# %% [markdown]
# ## Prelimiary steps

# %%
# Optional cell if the current path already has the data and the file utils.py
# %cd .. 
# %cd ..

# %%
# Import modules
import h5py
import keras.layers as layers
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.models import Model

from utils import plot_red_comp, slicer, split


# Path to store training data
save_path = "./tests/jupyter-notebooks/models/train_ae_depth_{}"
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ###  Data manipulation

# %%
# Selecting data
dt_fl = "nn_data.h5"
dt_dst = "scaled_data"

# The percentage for the test is implicit
n_train = 0.8
n_valid = 0.1

# Select the variable to train
# 0: Temperature - 1: Pressure - 2: Velocity - None: all
var = None

# %% [markdown]
# Load the selected data and then split it.

# %%
# Open data file
f = h5py.File(dt_fl, "r")
dt = f[dt_dst]

# Split data file
idxs = split(dt.shape[0], n_train, n_valid)
slc_trn, slc_vld, slc_tst = slicer(dt.shape, idxs, var=var)
# Slice data
if var:
    x_train = dt[slc_trn][:, :, :, np.newaxis]
    x_val = dt[slc_vld][:, :, :, np.newaxis]
else:
    x_train = dt[slc_trn]
    x_val = dt[slc_vld]

# Convert the var into a slice
if var:
    slc = slice(var, var + 1)
else:
    slc = slice(var)

# %% [markdown]
# ### Autoencoder settings

# %%
# Activation function
act = "tanh"  # Convolutional layers activation function
act_lt = "tanh"  # Latent space layers activation function
# Depth multiplier of each layer
mult = [3, 3, 3]
# Number of filters of the decoding layers
flt = [3, 9, 27]
# Filter size
flt_size = 5
# Strides of each layer
strd = [2, 2, 5]
# Latent space size
lt_sz = 90

# Training settings
opt = "adam"  # Optimizer
loss = "mse"
epochs = 60
batch_size = 32

# %% [markdown]
# ### Build autoencoder

# %%
# Build the autoencoder neural network
tf.keras.backend.clear_session()
flt_tp = (flt_size, flt_size)
conv_kwargs = dict(activation=act, padding="same")
# Encoder
inputs = layers.Input(shape=x_train.shape[1:])
e = layers.DepthwiseConv2D(
    flt_tp, depth_multiplier=mult[0], strides=strd[0], **conv_kwargs
)(inputs)
e = layers.DepthwiseConv2D(
    flt_tp, depth_multiplier=mult[1], strides=strd[1], **conv_kwargs
)(e)
e = layers.DepthwiseConv2D(
    flt_tp, depth_multiplier=mult[2], strides=strd[2], **conv_kwargs
)(e)

# Latent space
l = layers.Flatten()(e)
l = layers.Dense(lt_sz, activation=act_lt)(l)

# Latent to decoder
dn_flt = flt[-1]
d_shp = (x_train.shape[1:-1] / np.prod(strd)).astype(int)
d_sz = np.prod(d_shp) * dn_flt
d = layers.Dense(d_sz, activation=act_lt)(l)
d = layers.Reshape(np.hstack((d_shp, dn_flt)))(d)
# Decoder
d = layers.Conv2DTranspose(flt[-1], flt_tp, strides=strd[-1], **conv_kwargs)(d)
d = layers.Conv2DTranspose(flt[-2], flt_tp, strides=strd[-2], **conv_kwargs)(d)
d = layers.Conv2DTranspose(flt[-3], flt_tp, strides=strd[-3], **conv_kwargs)(d)
decoded = layers.Conv2DTranspose(
    x_train.shape[-1], flt_tp, activation="linear", padding="same"
)(d)

# Mount the autoencoder
ae = Model(inputs, decoded, name="Convolutional Autoencoder")

# %%
# Show the architecture
ae.summary()
# Out:
# Model: "Convolutional Autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200, 100, 3)       0
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 100, 50, 9)        234
# _________________________________________________________________
# depthwise_conv2d_2 (Depthwis (None, 50, 25, 27)        702
# _________________________________________________________________
# depthwise_conv2d_3 (Depthwis (None, 10, 5, 81)         2106
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4050)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 90)                364590
# _________________________________________________________________
# dense_2 (Dense)              (None, 1350)              122850
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 10, 5, 27)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 50, 25, 27)        18252
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 100, 50, 9)        6084
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 200, 100, 3)       678
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 200, 100, 3)       228
# =================================================================
# Total params: 515,724
# Trainable params: 515,724
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Callbacks
# Early stopping to stop training when the validation loss start to increase
# The patience term is a number of epochs to wait before stop. Also, the
# 'restore_best_weights' is used to restore the best model against the
# validation dataset. It is necessary as not always the best model against
# the validation dataset is the last neural network weights.

# %%
# Callbacks
monitor = "val_loss"
patience = int(epochs * 0.3)
es = EarlyStopping(
    monitor=monitor, mode="min", patience=patience, restore_best_weights=True
)

# %% [markdown]
# ### Training

# %%
# Compile and train
ae.compile(optimizer=opt, loss=loss)
hist = ae.fit(
    x_train,
    x_train,
    epochs=epochs,
    batch_size=batch_size,
    shuffle=True,
    validation_data=(x_val, x_val),
    callbacks=[es],
)
# Out:
# Train on 1133 samples, validate on 141 samples
# Epoch 1/60
# 1133/1133 [==============================] - 4s 3ms/step - loss: 0.8458 - val_loss: 0.7152
# Epoch 2/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.6008 - val_loss: 0.5050
# Epoch 3/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.4366 - val_loss: 0.4333
# Epoch 4/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3878 - val_loss: 0.4030
# Epoch 5/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3683 - val_loss: 0.3882
# Epoch 6/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3575 - val_loss: 0.3801
# Epoch 7/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3513 - val_loss: 0.3758
# Epoch 8/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3484 - val_loss: 0.3733
# Epoch 9/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3447 - val_loss: 0.3693
# Epoch 10/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3406 - val_loss: 0.3661
# Epoch 11/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3382 - val_loss: 0.3622
# Epoch 12/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.3273 - val_loss: 0.2902
# Epoch 13/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.1786 - val_loss: 0.1403
# Epoch 14/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.1118 - val_loss: 0.1130
# Epoch 15/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0911 - val_loss: 0.1018
# Epoch 16/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0797 - val_loss: 0.0877
# Epoch 17/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0725 - val_loss: 0.0830
# Epoch 18/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0668 - val_loss: 0.0767
# Epoch 19/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0630 - val_loss: 0.0738
# Epoch 20/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0587 - val_loss: 0.0712
# Epoch 21/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0564 - val_loss: 0.0686
# Epoch 22/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0552 - val_loss: 0.0682
# Epoch 23/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0534 - val_loss: 0.0655
# Epoch 24/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0506 - val_loss: 0.0625
# Epoch 25/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0487 - val_loss: 0.0618
# Epoch 26/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0473 - val_loss: 0.0601
# Epoch 27/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0461 - val_loss: 0.0603
# Epoch 28/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0470 - val_loss: 0.0618
# Epoch 29/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0461 - val_loss: 0.0586
# Epoch 30/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0447 - val_loss: 0.0572
# Epoch 31/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0434 - val_loss: 0.0562
# Epoch 32/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0421 - val_loss: 0.0548
# Epoch 33/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0409 - val_loss: 0.0540
# Epoch 34/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0400 - val_loss: 0.0545
# Epoch 35/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0398 - val_loss: 0.0538
# Epoch 36/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0393 - val_loss: 0.0533
# Epoch 37/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0391 - val_loss: 0.0516
# Epoch 38/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0386 - val_loss: 0.0524
# Epoch 39/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0382 - val_loss: 0.0530
# Epoch 40/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0384 - val_loss: 0.0524
# Epoch 41/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0377 - val_loss: 0.0511
# Epoch 42/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0375 - val_loss: 0.0543
# Epoch 43/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0379 - val_loss: 0.0522
# Epoch 44/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0379 - val_loss: 0.0510
# Epoch 45/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0367 - val_loss: 0.0497
# Epoch 46/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0364 - val_loss: 0.0500
# Epoch 47/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0368 - val_loss: 0.0512
# Epoch 48/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0366 - val_loss: 0.0501
# Epoch 49/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0355 - val_loss: 0.0493
# Epoch 50/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0347 - val_loss: 0.0482
# Epoch 51/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0344 - val_loss: 0.0479
# Epoch 52/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0339 - val_loss: 0.0482
# Epoch 53/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0338 - val_loss: 0.0496
# Epoch 54/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0341 - val_loss: 0.0476
# Epoch 55/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0338 - val_loss: 0.0478
# Epoch 56/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0331 - val_loss: 0.0473
# Epoch 57/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0329 - val_loss: 0.0471
# Epoch 58/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0328 - val_loss: 0.0466
# Epoch 59/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0325 - val_loss: 0.0474
# Epoch 60/60
# 1133/1133 [==============================] - 2s 2ms/step - loss: 0.0331 - val_loss: 0.0477

# %% [markdown]
# ### Save trained model

# %%
# Save the model
ae.save(save_path.format("model.h5"))

# Store the test dataset
if var:
    x_tst = dt[slc_tst][:, :, :, np.newaxis]
else:
    x_tst = dt[slc_tst]
np.save(save_path.format("test.npy"), x_tst)

# %% [markdown]
# ### Training process

# %%
# Convert the history to a Pandas dataframe
hist_df = pd.DataFrame(hist.history)
hist_df.index.name = "Epochs"
# Save the training history
hist_df.to_hdf(save_path.format("hist.h5"), 'his')

# Plot training evolution
tit = "Validation loss: {:.3f} - Training loss: {:.3f}".format(*hist_df.min())
hist_df.plot(grid=True, title=tit)

# %% [markdown]
# ### Evaluate the trained model

# %%
# Test the trained neural network against the test dataset
if var:
    x_test = dt[slc_tst][:, :, :, np.newaxis]
else:
    x_test = dt[slc_tst]
loss = ae.evaluate(x_test, x_test)
print("Test dataset loss: {:.3f}".format(loss))

global_loss = ae.evaluate(dt[:, :, :, slc], dt[:, :, :, slc])
print("Entire dataset loss: {:.3f}".format(global_loss))
# Out:
# 141/141 [==============================] - 0s 946us/step
# Test dataset loss: 0.047
# 1415/1415 [==============================] - 1s 829us/step
# Entire dataset loss: 0.035

# %%
# Comparing the input and output of the autoencoder neural network
data_index = 634

# Slice the data
dt_in = dt[data_index, :, :, slc]
# Get the neural network output
dt_out = ae.predict(dt_in[np.newaxis])
# Plot
alg = "Depthwise conv. autoencoder"

# %% [markdown]
# Plot temperature distribution

# %%
var_plt = 0
plot_red_comp(dt_in, dt_out[0], var_plt, lt_sz, global_loss, alg)

# %% [markdown]
# Plot pressure distribution

# %%
var_plt = 1
plot_red_comp(dt_in, dt_out[0], var_plt, lt_sz, global_loss, alg)

# %% [markdown]
# Plot velocity distribution

# %%
var_plt = 2
plot_red_comp(dt_in, dt_out[0], var_plt, lt_sz, global_loss, alg)
